# %%
pwd
# Out:
# 'c:\\Users\\ediad\\Documents\\Performance_Energetique\\Performance_Energetique\\Notebooks'

# %%
import pandas  as  pd

df_existant =  pd.read_csv('data.csv')
df_existant
# Out:
#      Unnamed: 0  Conso_chauffage_dépensier_é_finale  Emission_GES_ECS  \
# 0             0                             17273.3               1.5
# 1             1                              1983.8               3.1
# 2             2                             13225.9             347.4
# 3             3                              6166.2             389.0
# 4             4                             48701.8             534.4
# ..          ...                                 ...               ...
# 842         842                              4402.1             142.4
# 843         843                              1296.0              91.4
# 844         844                              3164.7             114.2
# 845         845                              4288.7             139.5
# 846         846                              5516.3             355.3
#
#     Type_énergie_n°1 Nom__commune_(BAN)  Coût_ECS_énergie_n°2  \
# 0        Électricité              Genas                   0.0
# ...
